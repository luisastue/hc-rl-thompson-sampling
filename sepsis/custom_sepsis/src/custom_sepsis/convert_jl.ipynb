# %%
include("models/ppl/main.jl")
using PyCall;
using Revise;
using Gen;
using CairoMakie
using Serialization
sepsis_gym = pyimport("custom_sepsis");

# %%
run_data = load_jld("data/mcmc/runs/SoftmaxPPL-every-1.jld")
# Out:
# RunData("SoftmaxPPL-every-1", :Softmax, ModelData(DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(:episodes => DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(56 => DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(:trajectory => DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(1 => DynamicChoiceMap(Dict{Any, Any}(:o2 => NORMAL, :hr => LOW, :bp => HIGH, :glu => LOW), Dict{Any, Any}()))))), 35 => DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(:trajectory => DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(4 => DynamicChoiceMap(Dict{Any, Any}(:o2 => NORMAL, :hr => LOW, :bp => LOW, :glu => SUPER_LOW), Dict{Any, Any}()), 2 => DynamicChoiceMap(Dict{Any, Any}(:o2 => NORMAL, :hr => LOW, :bp => NORMAL, :glu => SUPER_LOW), Dict{Any, Any}()), 3 => DynamicChoiceMap(Dict{Any, Any}(:o2 => NORMAL, :hr => LOW, :bp => NORMAL, :glu => SUPER_LOW), Dict{Any, Any}()), 1 => DynamicChoiceMap(Dict{Any, Any}(:o2 => NORMAL, :hr => LOW, :bp => NORMAL, :glu => SUPER_LOW), Dict{Any, Any}()))))), 110 =>
# ...
