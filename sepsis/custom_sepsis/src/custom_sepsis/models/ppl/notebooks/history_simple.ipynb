# %%
include("../main.jl")
using PyCall;
using Revise;
using Gen;
using CairoMakie
using Serialization
sepsis_gym = pyimport("custom_sepsis");

# %%
simple_model = MCMCModel(:simple, choicemap(), [], []);

# %%
history = PPHistoryRun("simple", simple_model);

# %%
# history = load_jld("../../../data/mcmc/history/simple.jld")

# %%
simple_model = MCMCModel(:simple, choicemap(), [], []);
softmax_model = MCMCModel(:softmax, choicemap(), [], []);
simple = PPHistoryRun("simple-3", simple_model);
softmax = PPHistoryRun("softmax-3", softmax_model);

# %%
# softmax = load_jld("../../../data/mcmc/history/softmax.jld")
# Out:
# PPHistoryRun("softmax", MCMCModel(:softmax, DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(:episodes => DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(56 => DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(:trajectory => DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(1 => DynamicChoiceMap(Dict{Any, Any}(:o2 => NORMAL, :hr => LOW, :bp => HIGH, :glu => LOW), Dict{Any, Any}()))))), 35 => DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(:trajectory => DynamicChoiceMap(Dict{Any, Any}(), Dict{Any, Any}(5 => DynamicChoiceMap(Dict{Any, Any}(:o2 => NORMAL, :hr => HIGH, :bp => HIGH, :glu => LOW), Dict{Any, Any}()), 4 => DynamicChoiceMap(Dict{Any, Any}(:o2 => NORMAL, :hr => HIGH, :bp => NORMAL, :glu => LOW), Dict{Any, Any}()), 2 => DynamicChoiceMap(Dict{Any, Any}(:o2 => NORMAL, :hr => HIGH, :bp => NORMAL, :glu => LOW), Dict{Any, Any}()), 3 => DynamicChoiceMap(Dict{Any, Any}(:o2 => NORMAL, :hr => HIGH, :bp => NORMAL, :glu => LOW), Dict{Any, Any}()), 1 => DynamicChoiceMap(Dict{Any, Any
# ...

# %%
for i in 1:15000
    for model in [softmax]
        if i < 100 && log2(i) % 1 == 0 
            update_model!(model.model, i)
            run_history_mcmc!(model, i, 200)
            save_history_jld(model)
            println("Finished episode ", model.model.type, " ", i)
        end
    end
end
# Out:
# InterruptException:
#
# Stacktrace:
#  [1] getindex(h::Dict{Level, Float64}, key::Level)
#    @ Base ./dict.jl:496
#  [2] get_transition_matrix(parameters::Dict{Tuple{Symbol, Level, Symbol}, Vector{Float64}}, functions::SepsisParams)
#    @ Main.ValueIteration ~/thesis/hc-rl-thompson-sampling/sepsis/custom_sepsis/src/custom_sepsis/models/ppl/value_iter.jl:59
#  [3] optimize(parameters::Dict{Tuple{Symbol, Level, Symbol}, Vector{Float64}}, functions::SepsisParams)
#    @ Main.ValueIteration ~/thesis/hc-rl-thompson-sampling/sepsis/custom_sepsis/src/custom_sepsis/models/ppl/value_iter.jl:108
#  [4] run_history_mcmc!(history::PPHistoryRun, index::Int64, steps::Int64)
#    @ Main.History ~/thesis/hc-rl-thompson-sampling/sepsis/custom_sepsis/src/custom_sepsis/models/ppl/evaluate/history.jl:62
#  [5] top-level scope
#    @ ./In[8]:5
